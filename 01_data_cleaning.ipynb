# %%
import pandas as pd

# %%
ames = pd.read_csv('ames.csv')

# %%
ames.head(3)
# Out:
#    Order  MS SubClass MS Zoning  Lot Frontage  Lot Area Street Alley  \
# 0      1           20        RL         141.0     31770   Pave   NaN
# 1      2           20        RH          80.0     11622   Pave   NaN
# 2      3           20        RL          81.0     14267   Pave   NaN
#
#   Lot Shape Land Contour Utilities  ... Pool Area Pool QC  Fence Misc Feature  \
# 0       IR1          Lvl    AllPub  ...         0     NaN    NaN          NaN
# 1       Reg          Lvl    AllPub  ...         0     NaN  MnPrv          NaN
# 2       IR1          Lvl    AllPub  ...         0     NaN    NaN         Gar2
#
#   Misc Val Mo Sold Yr Sold  Sale Type  Sale Condition  SalePrice
# 0        0       5    2010        WD           Normal     215000
# 1        0       6    2010        WD           Normal     105000
# 2    12500       6    2010        WD           Normal     172000
#
# [3 rows x 81 columns]

# %%
ames.isnull().sum()

#display(len(df.isna().sum()) / len(df) * 100)
# Out:
# Order               0
# MS SubClass         0
# MS Zoning           0
# Lot Frontage      490
# Lot Area            0
#                  ...
# Mo Sold             0
# Yr Sold             0
# Sale Type           0
# Sale Condition      0
# SalePrice           0
# Length: 81, dtype: int64

# %%
ames.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2930 entries, 0 to 2929
# Data columns (total 81 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Order            2930 non-null   int64
#  1   MS SubClass      2930 non-null   int64
#  2   MS Zoning        2930 non-null   object
#  3   Lot Frontage     2440 non-null   float64
#  4   Lot Area         2930 non-null   int64
#  5   Street           2930 non-null   object
#  6   Alley            198 non-null    object
#  7   Lot Shape        2930 non-null   object
#  8   Land Contour     2930 non-null   object
#  9   Utilities        2930 non-null   object
#  10  Lot Config       2930 non-null   object
#  11  Land Slope       2930 non-null   object
#  12  Neighborhood     2930 non-null   object
#  13  Condition 1      2930 non-null   object
#  14  Condition 2      2930 non-null   object
#  15  Bldg Type        2930 non-null   object
# ...

# %%
summed_nas = ames.isnull().sum()
summed_nas[summed_nas != 0]
# Out:
# Lot Frontage       490
# Alley             2732
# Mas Vnr Type        23
# Mas Vnr Area        23
# Bsmt Qual           80
# Bsmt Cond           80
# Bsmt Exposure       83
# BsmtFin Type 1      80
# BsmtFin SF 1         1
# BsmtFin Type 2      81
# BsmtFin SF 2         1
# Bsmt Unf SF          1
# Total Bsmt SF        1
# Electrical           1
# Bsmt Full Bath       2
# Bsmt Half Bath       2
# Fireplace Qu      1422
# Garage Type        157
# Garage Yr Blt      159
# Garage Finish      159
# Garage Cars          1
# Garage Area          1
# Garage Qual        159
# Garage Cond        159
# Pool QC           2917
# Fence             2358
# Misc Feature      2824
# dtype: int64

# %%
display(ames.isna().sum() /len(ames)*100)
# Out:
# Order              0.000000
# MS SubClass        0.000000
# MS Zoning          0.000000
# Lot Frontage      16.723549
# Lot Area           0.000000
#                     ...
# Mo Sold            0.000000
# Yr Sold            0.000000
# Sale Type          0.000000
# Sale Condition     0.000000
# SalePrice          0.000000
# Length: 81, dtype: float64

# %%
ames_remaining= ames.drop(['Alley', 'Fireplace Qu', 'Lot Frontage', 'Pool QC', 'Misc Feature', 'Fence', ], axis=1)
ames_remaining
# Out:
#       Order  MS SubClass MS Zoning  Lot Area Street Lot Shape Land Contour  \
# 0         1           20        RL     31770   Pave       IR1          Lvl
# 1         2           20        RH     11622   Pave       Reg          Lvl
# 2         3           20        RL     14267   Pave       IR1          Lvl
# 3         4           20        RL     11160   Pave       Reg          Lvl
# 4         5           60        RL     13830   Pave       IR1          Lvl
# ...     ...          ...       ...       ...    ...       ...          ...
# 2925   2926           80        RL      7937   Pave       IR1          Lvl
# 2926   2927           20        RL      8885   Pave       IR1          Low
# 2927   2928           85        RL     10441   Pave       Reg          Lvl
# 2928   2929           20        RL     10010   Pave       Reg          Lvl
# 2929   2930           60        RL      9627   Pave       Reg          Lvl
#
# ...

# %%
ames_remaining.corr()
# Out:
#                     Order  MS SubClass  Lot Area  Overall Qual  Overall Cond  \
# Order            1.000000     0.011797  0.031354     -0.048500     -0.011054
# MS SubClass      0.011797     1.000000 -0.204613      0.039419     -0.067349
# Lot Area         0.031354    -0.204613  1.000000      0.097188     -0.034759
# Overall Qual    -0.048500     0.039419  0.097188      1.000000     -0.094812
# Overall Cond    -0.011054    -0.067349 -0.034759     -0.094812      1.000000
# Year Built      -0.052319     0.036579  0.023258      0.597027     -0.368773
# Year Remod/Add  -0.075566     0.043397  0.021682      0.569609      0.047680
# Mas Vnr Area    -0.030907     0.002730  0.126830      0.429418     -0.135340
# BsmtFin SF 1    -0.032321    -0.060075  0.191555      0.284118     -0.050935
# BsmtFin SF 2    -0.002773    -0.070946  0.083150     -0.041287      0.041134
# Bsmt Unf SF      0.005780    -0.130421  0.023658      0.270058     -0.136819
# ...

# %%
ames_remaining.corr().sort_values(by = ["SalePrice"], ascending = False)
# Out:
#                     Order  MS SubClass  Lot Area  Overall Qual  Overall Cond  \
# SalePrice       -0.031408    -0.085092  0.266549      0.799262     -0.101697
# Overall Qual    -0.048500     0.039419  0.097188      1.000000     -0.094812
# Gr Liv Area     -0.009342     0.068061  0.285599      0.570556     -0.115643
# Garage Cars     -0.036185    -0.045883  0.179512      0.599545     -0.181557
# Garage Area     -0.035435    -0.103239  0.212822      0.563503     -0.153754
# Total Bsmt SF   -0.028719    -0.219445  0.253589      0.547294     -0.173344
# 1st Flr SF      -0.013201    -0.247828  0.332235      0.477837     -0.157052
# Year Built      -0.052319     0.036579  0.023258      0.597027     -0.368773
# Full Bath       -0.044985     0.134631  0.127433      0.522263     -0.214316
# Year Remod/Add  -0.075566     0.043397  0.021682      0.569609      0.047680
# Garage Yr Blt   -0.051160     0.088754 -0.008952      0.570569     -0.326017
# ...

# %% [markdown]
# ames_remaining.corr().sort_values(by = ["SalePrice"], ascending = False)

# %%
ames_to_use = ames_remaining[['Overall Qual', 'Gr Liv Area', 'Garage Cars', 'Garage Area', 'Total Bsmt SF', '1st Flr SF', 'Year Built', 'Full Bath', 'Year Remod/Add', 'Garage Yr Blt', 'Mas Vnr Area', 'SalePrice']]
ames_to_use
# Out:
#       Overall Qual  Gr Liv Area  Garage Cars  Garage Area  Total Bsmt SF  \
# 0                6         1656          2.0        528.0         1080.0
# 1                5          896          1.0        730.0          882.0
# 2                6         1329          1.0        312.0         1329.0
# 3                7         2110          2.0        522.0         2110.0
# 4                5         1629          2.0        482.0          928.0
# ...            ...          ...          ...          ...            ...
# 2925             6         1003          2.0        588.0         1003.0
# 2926             5          902          2.0        484.0          864.0
# 2927             5          970          0.0          0.0          912.0
# 2928             5         1389          2.0        418.0         1389.0
# 2929             7         2000          3.0        650.0          996.0
#
#       1st Flr SF  Year Built  Full Bath  Year Remod/Add  Garage Yr Blt  \
# ...

# %%
ames_to_use.dtypes
# Out:
# Overall Qual        int64
# Gr Liv Area         int64
# Garage Cars       float64
# Garage Area       float64
# Total Bsmt SF     float64
# 1st Flr SF          int64
# Year Built          int64
# Full Bath           int64
# Year Remod/Add      int64
# Garage Yr Blt     float64
# Mas Vnr Area      float64
# SalePrice           int64
# dtype: object

# %%
ames_to_use.isna().sum()
# Out:
# Overall Qual        0
# Gr Liv Area         0
# Garage Cars         1
# Garage Area         1
# Total Bsmt SF       1
# 1st Flr SF          0
# Year Built          0
# Full Bath           0
# Year Remod/Add      0
# Garage Yr Blt     159
# Mas Vnr Area       23
# SalePrice           0
# dtype: int64

# %%
ames_final = ames_to_use.drop(["Garage Yr Blt"], axis =1)
ames_final.isna().sum()
# Out:
# Overall Qual       0
# Gr Liv Area        0
# Garage Cars        1
# Garage Area        1
# Total Bsmt SF      1
# 1st Flr SF         0
# Year Built         0
# Full Bath          0
# Year Remod/Add     0
# Mas Vnr Area      23
# SalePrice          0
# dtype: int64

# %%
ames_final_nona = ames_final.dropna()
ames_final_nona.shape[0]
# Out:
# 2905

# %%
ames_final_nona.dtypes
# Out:
# Overall Qual        int64
# Gr Liv Area         int64
# Garage Cars       float64
# Garage Area       float64
# Total Bsmt SF     float64
# 1st Flr SF          int64
# Year Built          int64
# Full Bath           int64
# Year Remod/Add      int64
# Mas Vnr Area      float64
# SalePrice           int64
# dtype: object

# %%
ames_final_nona.describe()
# Out:
#        Overall Qual  Gr Liv Area  Garage Cars  Garage Area  Total Bsmt SF  \
# count   2905.000000  2905.000000  2905.000000  2905.000000    2905.000000
# mean       6.086403  1498.503614     1.764544   472.341480    1050.524613
# std        1.409984   506.307777     0.761267   215.226042     440.657122
# min        1.000000   334.000000     0.000000     0.000000       0.000000
# 25%        5.000000  1124.000000     1.000000   320.000000     792.000000
# 50%        6.000000  1440.000000     2.000000   479.000000     990.000000
# 75%        7.000000  1740.000000     2.000000   576.000000    1300.000000
# max       10.000000  5642.000000     5.000000  1488.000000    6110.000000
#
#         1st Flr SF   Year Built    Full Bath  Year Remod/Add  Mas Vnr Area  \
# count  2905.000000  2905.000000  2905.000000     2905.000000   2905.000000
# mean   1159.108778  1971.133907     1.562823     1984.119105    101.966954
# std     391.464186    30.216510     0.551976       20.857882    179.154308
# ...

# %%
ames_final_nona.columns = (ames_final_nona.columns
                           .str.lower()
                           .str.replace(' ', '_'))

# %%
ames_final_nona
# Out:
#       overall_qual  gr_liv_area  garage_cars  garage_area  total_bsmt_sf  \
# 0                6         1656          2.0        528.0         1080.0
# 1                5          896          1.0        730.0          882.0
# 2                6         1329          1.0        312.0         1329.0
# 3                7         2110          2.0        522.0         2110.0
# 4                5         1629          2.0        482.0          928.0
# ...            ...          ...          ...          ...            ...
# 2925             6         1003          2.0        588.0         1003.0
# 2926             5          902          2.0        484.0          864.0
# 2927             5          970          0.0          0.0          912.0
# 2928             5         1389          2.0        418.0         1389.0
# 2929             7         2000          3.0        650.0          996.0
#
#       1st_flr_sf  year_built  full_bath  year_remod/add  mas_vnr_area  \
# ...

# %%
ames_final_nona.to_csv('ames_clean.csv')
